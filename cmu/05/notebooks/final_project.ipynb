# %% [markdown]
# # Final Project
#
# This is a blank notebook that you can use to create your final project! Click the button to create this notebook.
#
# <a target="_blank" href="https://jupyter-k12.org?github=simonguest/codercub/blob/main/cmu/05/notebooks/final_project.ipynb">
#   <img src="https://img.shields.io/badge/Open_in-Jupyter_K--12-blue" alt="Open In Jupyter K-12"/>
# </a>
#
# Note: If you've already created your final project notebook, visit [Jupyter-k12](https://jupyter-k12.org) and open it from your list of notebooks instead.

# %%
import scene3d

scene = scene3d.Scene()

# What are you going to create?!
