# %% [markdown]
# # Final Project
#
# This is a blank notebook that you can use to create your final project! Click the button to create this notebook.
#
# <a target="_blank" href="https://codetto.app?github=simonguest/codercub/blob/main/cmu/05/notebooks/final_project.ipynb">
#   <img src="https://img.shields.io/badge/Open_in-Codetto-blue" alt="Open In Codetto"/>
# </a>
#
# Note: If you've already created your final project notebook, visit [Jupyter-k12](https://codetto.app) and open it from your list of notebooks instead.

# %%
import scene3d

scene = scene3d.Scene()

# What are you going to create?!
